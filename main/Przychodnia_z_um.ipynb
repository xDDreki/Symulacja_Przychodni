# %%
import matplotlib
matplotlib.use('TkAgg')  # or 'Qt5Agg'
import numpy as np
import simpy
import matplotlib.pyplot as plt
import random
import pandas as pd

# %%
class Patient:
    def __init__(self, id):
        self.id = id
        self.arrival_time = None
        self.service_start_time = None
        self.service_end_time = None
        self.room = None
        self.real_service_time = None

# %%
class Room:
    def __init__(self, id, env):
        self.id = id
        self.patients_served = 0
        self.no_show = 0
        self.queue = []
        self.queue_len_dict = dict()
        self.resource = simpy.Resource(env, capacity=1)
    def update_queue_len_dict(self, curr_time):
        self.queue_len_dict[curr_time] = len(self.queue)

# %%
class Clinic:
    def __init__(self, number_of_rooms, planned_service_time, no_show=0.2, seed=None, sim_time=480):
        self.curr_patient_id = 1
        self.env = simpy.Environment()
        self.planned_service_time = planned_service_time
        self.no_show = no_show
        self.seed = seed
        self.list_rooms = [Room(id=i + 1, env=self.env) for i in range(number_of_rooms)]
        self.processed_patients = []
        self.sim_time = sim_time

        if self.seed:
            random.seed(self.seed)
            np.random.seed(self.seed)

    def readable_time(self):
        hours = 8 + int(self.env.now // 60)
        minutes = int(self.env.now % 60)
        if len(str(minutes)) == 1:
            return f"{hours}:0{minutes}"
        return f"{hours}:{minutes}"

    def generate_patients(self, room):

        def randomized_service_time(mean=15, std=2):
            return max(np.random.normal(mean, std), 1)

        def time_between_new_patients():
            return self.planned_service_time

        while True:
            if self.env.now > self.sim_time - self.planned_service_time:  # Pacjenci nie przychodzą przed {service_time} zamknięciem
                break

            patient = Patient(id=f"{room.id}.{self.curr_patient_id}")
            patient.room = room.id
            patient.real_service_time = randomized_service_time()

            if random.random() < self.no_show:  #pacjent nie przyszedl
                print(f'Czas {self.readable_time()}: Pacjent {patient.id} nie pojawił w gabinecie {room.id} w ciągu {self.planned_service_time} minut')
                room.no_show += 1

            else:  #pacjent przyszedl
                patient.arrival_time = self.env.now
                print(f"Czas {self.readable_time()}: Pacjent {patient.id} przybył do kliniki")
                self.env.process(self.serve_patient(patient, room))

            self.curr_patient_id += 1
            yield self.env.timeout(time_between_new_patients())

    def serve_patient(self, patient, room):
        room.queue.append(patient.id)
        room.update_queue_len_dict(curr_time=self.env.now)

        with room.resource.request() as request:
            yield request
            patient.service_start_time = self.env.now
            room.queue.remove(patient.id)
            room.update_queue_len_dict(curr_time=self.env.now)

            print(f"Czas {self.readable_time()}: Pacjent {patient.id} wchodzi do gabinetu {room.id} ")

            yield self.env.timeout(patient.real_service_time)

            patient.service_end_time = self.env.now
            room.patients_served += 1
            print(f"Czas {self.readable_time()}: Pacjent {patient.id} wychodzi z gabinetu {room.id}")
            self.processed_patients.append(patient)

    # def reset(self):
    #     self.env = simpy.Environment()
    #     self.curr_patient_id = 1
    #     self.list_rooms = [Gabinet(id=i + 1) for i in range(len(self.list_rooms))]
    #     self.rooms = simpy.Store(self.env, capacity=len(self.list_rooms))
    #     for room in self.list_rooms:
    #         self.rooms.put(room)
    #     self.processed_patients = []
    #     # ----
    #     self.env = simpy.Environment()
    #     self.curr_patient_id = 1
    #     self.planned_service_time = planned_service_time
    #     self.no_show = no_show
    #     self.seed = seed
    #     self.list_rooms = [Room(id=i + 1, env=self.env) for i in range(number_of_rooms)]
    #     self.processed_patients = []
    #     self.sim_time = sim_time

    def run(self, day=1):
        def sum_queue_len_data():
            all_times = set()
            for room in self.list_rooms:
                all_times.update(room.queue_len_dict.keys())

            all_times = sorted(all_times)
            queue_data = []
            last_known = {room.id: 0 for room in self.list_rooms}  # cache

            for time in all_times:
                for room in self.list_rooms:
                    if time in room.queue_len_dict:
                        last_known[room.id] = room.queue_len_dict[time]

                total_queue = sum(last_known.values())
                queue_data.append({
                    'day': day,
                    'time': time,
                    'total_queue_length': total_queue
                })
            queue_data = pd.DataFrame(queue_data)
            queue_data = queue_data.set_index(["day", "time"])
            return queue_data
        
        for room in self.list_rooms:
            self.env.process(self.generate_patients(room))
        self.env.run(until=self.sim_time + 0.01)
        df = pd.DataFrame([
            {
                "day": day,
                "id": p.id,
                "room": p.room,
                "arrival_time": p.arrival_time,
                "service_start_time": p.service_start_time,
                "service_end_time": p.service_end_time,
                "service_time": p.service_end_time - p.service_start_time,
                "waiting_time": p.service_start_time - p.arrival_time
            }
            for p in self.processed_patients
        ])
        df = df.set_index("id")
        queue_df = sum_queue_len_data()
        return df, queue_df

    def run_multiple_times(self, n):

        # sum_no_show = 0
        # sum_patients_served = 0

        for i in range(1, n + 1):
            print(f"-----------{i}-----------")
            self.env = simpy.Environment()
            self.curr_patient_id = 1
            self.list_rooms = [Room(id=i + 1, env=self.env) for i in range(len(self.list_rooms))]
            self.processed_patients = []
            single_df, single_queue_df = self.run(i)

            # for room in self.list_rooms:
            #     sum_no_show += room.no_show
            #     sum_patients_served += room.patients_served

            multiple_df = pd.concat([multiple_df, single_df], ignore_index=True) if i > 1 else single_df
            multiple_queue_df = pd.concat([multiple_queue_df, single_queue_df]) if i > 1 else single_queue_df
        # return multiple_df, sum_patients_served, sum_no_show
        return multiple_df, multiple_queue_df

# %%
clinic1 = Clinic(number_of_rooms=3, planned_service_time=15, sim_time=120)

# %%
df, q_df = clinic1.run()
# Out:
# Czas 8:00: Pacjent 1.1 przybył do kliniki
# Czas 8:00: Pacjent 2.2 nie pojawił w gabinecie 2 w ciągu 15 minut
# Czas 8:00: Pacjent 3.3 nie pojawił w gabinecie 3 w ciągu 15 minut
# Czas 8:00: Pacjent 1.1 wchodzi do gabinetu 1
# Czas 8:13: Pacjent 1.1 wychodzi z gabinetu 1
# Czas 8:15: Pacjent 1.4 przybył do kliniki
# Czas 8:15: Pacjent 2.5 przybył do kliniki
# Czas 8:15: Pacjent 3.6 przybył do kliniki
# Czas 8:15: Pacjent 1.4 wchodzi do gabinetu 1
# Czas 8:15: Pacjent 2.5 wchodzi do gabinetu 2
# Czas 8:15: Pacjent 3.6 wchodzi do gabinetu 3
# Czas 8:27: Pacjent 1.4 wychodzi z gabinetu 1
# Czas 8:29: Pacjent 2.5 wychodzi z gabinetu 2
# Czas 8:30: Pacjent 1.7 przybył do kliniki
# Czas 8:30: Pacjent 2.8 nie pojawił w gabinecie 2 w ciągu 15 minut
# Czas 8:30: Pacjent 3.9 przybył do kliniki
# Czas 8:30: Pacjent 1.7 wchodzi do gabinetu 1
# Czas 8:30: Pacjent 3.6 wychodzi z gabinetu 3
# Czas 8:30: Pacjent 3.9 wchodzi do gabinetu 3
# Czas 8:44: Pacjent 1.7 wychodzi z gabinetu 1
# ...

# %%
display(df)
# Out:
#       day  room  arrival_time  service_start_time  service_end_time  \
# id
# 1.1     1     1             0            0.000000         13.814933
# 1.4     1     1            15           15.000000         27.464361
# 2.5     1     2            15           15.000000         29.926871
# 3.6     1     3            15           15.000000         30.878880
# 1.7     1     1            30           30.000000         44.699753
# 3.9     1     3            30           30.878880         46.506976
# 2.11    1     2            45           45.000000         58.783939
# 1.10    1     1            45           45.000000         59.706860
# 3.12    1     3            45           46.506976         62.145497
# 3.15    1     3            60           62.145497         75.005773
# 1.13    1     1            60           60.000000         75.640157
# 3.18    1     3            75           75.005773         87.904755
# 1.16    1     1            75           75.640157         91.041564
# ...

# %%
display(q_df)
# Out:
#                 total_queue_length
# day time
# 1   0.000000                     0
#     15.000000                    0
#     30.000000                    1
#     30.878880                    0
#     45.000000                    1
#     46.506976                    0
#     60.000000                    1
#     62.145497                    0
#     75.000000                    2
#     75.005773                    1
#     75.640157                    0
#     90.000000                    1
#     91.051556                    0
#     105.000000                   1
#     107.198994                   0

# %%
df1, q_df1 = clinic1.run_multiple_times(10)
# Out:
# -----------1-----------
# Czas 8:00: Pacjent 1.1 nie pojawił w gabinecie 1 w ciągu 15 minut
# Czas 8:00: Pacjent 2.2 przybył do kliniki
# Czas 8:00: Pacjent 3.3 przybył do kliniki
# Czas 8:00: Pacjent 2.2 wchodzi do gabinetu 2
# Czas 8:00: Pacjent 3.3 wchodzi do gabinetu 3
# Czas 8:13: Pacjent 3.3 wychodzi z gabinetu 3
# Czas 8:14: Pacjent 2.2 wychodzi z gabinetu 2
# Czas 8:15: Pacjent 1.4 przybył do kliniki
# Czas 8:15: Pacjent 2.5 nie pojawił w gabinecie 2 w ciągu 15 minut
# Czas 8:15: Pacjent 3.6 przybył do kliniki
# Czas 8:15: Pacjent 1.4 wchodzi do gabinetu 1
# Czas 8:15: Pacjent 3.6 wchodzi do gabinetu 3
# Czas 8:27: Pacjent 3.6 wychodzi z gabinetu 3
# Czas 8:30: Pacjent 1.7 przybył do kliniki
# Czas 8:30: Pacjent 2.8 przybył do kliniki
# Czas 8:30: Pacjent 3.9 przybył do kliniki
# Czas 8:30: Pacjent 2.8 wchodzi do gabinetu 2
# Czas 8:30: Pacjent 3.9 wchodzi do gabinetu 3
# Czas 8:31: Pacjent 1.4 wychodzi z gabinetu 1
# Czas 8:31: Pacjent 1.7 wchodzi do gabinetu 1
# ...

# %%
display(df1)
# Out:
#      day  room  arrival_time  service_start_time  service_end_time  \
# 0      1     3             0            0.000000         13.805459
# 1      1     2             0            0.000000         14.417552
# 2      1     3            15           15.000000         27.466220
# 3      1     1            15           15.000000         31.375186
# 4      1     1            30           31.375186         45.407622
# ..   ...   ...           ...                 ...               ...
# 173   10     1            75           78.787434         93.660794
# 174   10     2            90           91.517454        104.506329
# 175   10     3            90           92.542162        104.656935
# 176   10     1            90           93.660794        108.916414
# 177   10     3           105          105.000000        117.749012
#
#      service_time  waiting_time
# 0       13.805459      0.000000
# 1       14.417552      0.000000
# 2       12.466220      0.000000
# ...

# %%
display(q_df1)
# Out:
#                 total_queue_length
# day time
# 1   0.000000                     0
#     15.000000                    0
#     30.000000                    1
#     31.375186                    0
#     45.000000                    3
# ...                            ...
# 10  91.517454                    2
#     92.542162                    1
#     93.660794                    0
#     105.000000                   1
#     108.916414                   0
#
# [173 rows x 1 columns]

# %%
q_df1['total_queue_length'].value_counts()
# Out:
# total_queue_length
# 0    80
# 1    57
# 2    31
# 3     5
# Name: count, dtype: int64

# %%
df1['service_start_time'].value_counts()
# Out:
# service_start_time
# 0.000000     26
# 15.000000    16
# 75.000000    14
# 30.000000    10
# 45.000000    10
#              ..
# 61.559231     1
# 78.787434     1
# 91.517454     1
# 92.542162     1
# 93.660794     1
# Name: count, Length: 90, dtype: int64
