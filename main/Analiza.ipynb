# %%
import pandas as pd
from analiza_statystyczna import z_test_waiting_times

#Naprawa importów pomocniczych funkcji po edycji ich kodu
import importlib
import analiza_statystyczna
importlib.reload(analiza_statystyczna)
# Out:
# <module 'analiza_statystyczna' from 'c:\\Users\\lukas\\OneDrive\\Pulpit\\projekty\\Symulacja_Przychodni\\main\\analiza_statystyczna.py'>

# %%
df_bez_um = pd.read_csv("../wyniki/wyniki_bez_um.csv")
df_z_um = pd.read_csv("../wyniki/wyniki_z_um.csv")

wyniki = z_test_waiting_times(df_bez_um, df_z_um, alpha=0.05)
# Out:
# ...
# Z-TEST: PORÓWNANIE CZASÓW OCZEKIWANIA
# ...
#
# --- System BEZ UMAWIANIA ---
# Średnia: 8.50 min
# Odchylenie std: 11.49 min
# Liczba obserwacji: 76569
#
# --- System Z UMAWIANIEM ---
# Średnia: 1.05 min
# Odchylenie std: 1.82 min
# Liczba obserwacji: 17540
#
# --- RÓŻNICA ---
# Δμ = 7.44 min
#
# --- WYNIKI Z-TESTU ---
# Z-statystyka: 170.2500
# P-value (jednostronny): 0.000000
# Poziom istotności alfa: 0.05
#
# --- WNIOSKI ---
# ODRZUCAMY H0 (p < 0.05)
# System Z UMAWIANIEM ma ISTOTNIE NIŻSZE czasy oczekiwania
# ...
