# %% [markdown]
# # Sanity check
# ## 1. Cel sprawozdania
# Celem tego pliku jest dokumentacja kodu oraz przebadanie poprawności naszej symulacji poprzez porównanie z teoretycznym, spodziewanym wynikiem.

# %%
import matplotlib
matplotlib.use('TkAgg')  # or 'Qt5Agg'
import numpy as np
import simpy
import seaborn
import matplotlib.pyplot as plt

# %%
class Pacjent:
    def __init__(self, id):
        self.id = id
        self.arrival_time = None
        self.service_start_time = None
        self.service_end_time = None

# %%
class Gabinet:
    def __init__(self, id, env):
        self.id = id
        self.env = env
        self.patients_served = 0

# %% [markdown]
# # Parametry kliniki:
# - **number_of_ rooms**: liczba gabinetów
# - **service_time**: Jak długo obsługiwany jest pacjent [minuty]
# - **lambda_per_hour**: Ile pacjentów przychodzi co godzinę (dzieli się przez 60 bo zamieniamy na minuty)
# - **sim_time**: Długość symulacji
#
# # Pomocnicze zmienne:
# - **queue_array**: Kolejka (podgląd czekających pacjentów)
# - **seed**: seed generatora liczb pseudolosowych

# %%
class Clinic:
    def __init__(self, env, number_of_rooms, service_time, queue_array=[], lambda_per_hour=12/60, seed=None, sim_time=480):
        self.curr_patient_id = 1
        self.env = env
        self.service_time = service_time
        self.lambda_per_hour = lambda_per_hour
        self.seed = seed
        self.list_rooms = [Gabinet(id=i + 1, env=self.env) for i in range(number_of_rooms)]
        self.rooms = simpy.Store(self.env, capacity=number_of_rooms)
        self.sim_time = sim_time
        self.queue_array = queue_array
        for room in self.list_rooms:
            self.rooms.put(room)
        self.processed_patients = []

    def czas(self, time_in_minutes):
        hours = 9+time_in_minutes//60
        minutes = time_in_minutes%60
        if len(str(int(minutes)))==1:
            return f"{int(hours)}:0{int(minutes)}"
        return f"{int(hours)}:{int(minutes)}"

    def time_between_new_patients(self):
        if self.seed:
            np.random.seed(self.seed)
        return np.random.exponential(1/self.lambda_per_hour)
    
    def generate_patients(self):
        while True:
            if self.env.now >= self.sim_time-self.service_time: # Pacjenci nie przychodzą przed {service_time} zamknięciem
                break
            patient = Pacjent(id=self.curr_patient_id)
            patient.arrival_time = self.env.now
            print(f"Czas {self.czas(np.trunc(self.env.now))}: Pacjent {patient.id} przybył do kliniki")
            self.env.process(self.serve_patient(patient))
            self.curr_patient_id += 1
            yield self.env.timeout(self.time_between_new_patients())

    def serve_patient(self, patient): 
        room = yield self.rooms.get()
        self.queue_array.append(patient.id)
        if self.env.now >= self.sim_time-self.service_time: # Nie zdążyło obsłużyć pacjenta przed zamknięciem
            print(f"Czas {self.czas(np.trunc(self.env.now))}: Pacjent {patient.id} - nie zdążył zostać obsłużony przed zamknięciem kliniki")
            yield self.rooms.put(room)
            return
        patient.service_start_time = self.env.now
        print(f"Czas {self.czas(np.trunc(self.env.now))}: Pacjent {patient.id} wchodzi do gabinetu {room.id} ")
        self.queue_array.remove(patient.id)
        yield self.env.timeout(self.service_time)

        patient.service_end_time = self.env.now
        room.patients_served += 1
        print(f"Czas {self.czas(np.trunc(self.env.now))}: Pacjent {patient.id} wychodzi z gabinetu {room.id}, czekal od {self.czas(np.trunc(patient.arrival_time))} do {self.czas(np.trunc(patient.service_start_time))}")
        self.processed_patients.append(patient)
        yield self.rooms.put(room)

    def run(self):
        self.env.process(self.generate_patients())
        env.run(until=self.sim_time)

    def stats(self):
        def patient_bar_plot():
            patients_served_ls = []
            id_ls = []
            for room in self.list_rooms:
                patients_served_ls.append(room.patients_served)
                id_ls.append(str(room.id))
            fig = seaborn.barplot(x=id_ls, y=patients_served_ls)
            fig.set_xlabel('Gabinet')
            fig.set_ylabel('Ilosc Pacjentow')
            plt.savefig("patients_served_noshow.png")
            plt.show()

        patient_bar_plot()

# %%
#bez umawiania
env = simpy.Environment()

# %%
clinic = Clinic(env, number_of_rooms=3, service_time=15)

# %%
clinic.run()
# Out:
# Czas 9:00: Pacjent 1 przybył do kliniki
# Czas 9:00: Pacjent 1 wchodzi do gabinetu 1
# Czas 9:04: Pacjent 2 przybył do kliniki
# Czas 9:04: Pacjent 2 wchodzi do gabinetu 2
# Czas 9:15: Pacjent 1 wychodzi z gabinetu 1, czekal od 9:00 do 9:00
# Czas 9:19: Pacjent 2 wychodzi z gabinetu 2, czekal od 9:04 do 9:04
# Czas 9:27: Pacjent 3 przybył do kliniki
# Czas 9:27: Pacjent 3 wchodzi do gabinetu 3
# Czas 9:29: Pacjent 4 przybył do kliniki
# Czas 9:29: Pacjent 4 wchodzi do gabinetu 1
# Czas 9:32: Pacjent 5 przybył do kliniki
# Czas 9:32: Pacjent 5 wchodzi do gabinetu 2
# Czas 9:36: Pacjent 6 przybył do kliniki
# Czas 9:42: Pacjent 3 wychodzi z gabinetu 3, czekal od 9:27 do 9:27
# Czas 9:42: Pacjent 6 wchodzi do gabinetu 3
# Czas 9:44: Pacjent 4 wychodzi z gabinetu 1, czekal od 9:29 do 9:29
# Czas 9:47: Pacjent 5 wychodzi z gabinetu 2, czekal od 9:32 do 9:32
# Czas 9:57: Pacjent 7 przybył do kliniki
# Czas 9:57: Pacjent 7 wchodzi do gabinetu 1
# Czas 9:57: Pacjent 6 wychodzi z gabinetu 3, czekal od 9:36 do 9:42
# Czas 9:57: Pacjent 8 przybył do kliniki
# Czas 9:57: Pacjent 8 wchodzi do gabinetu 2
# Czas 10:02: Pacjent 9 przybył do kliniki
# Czas 10:02: Pacjent 9 wchodzi do gabinetu 3
# Czas 10:05: Pacjent 10 przybył do kliniki
# Czas 10:09: Pacjent 11 przybył do kliniki
# Czas 10:12: Pacjent 7 wychodzi z gabinetu 1, czekal od 9:57 do 9:57
# Czas 10:12: Pacjent 10 wchodzi do gabinetu 1
# Czas 10:12: Pacjent 8 wychodzi z gabinetu 2, czekal od 9:57 do 9:57
# Czas 10:12: Pacjent 11 wchodzi do gabinetu 2
# Czas 10:13: Pacjent 12 przybył do kliniki
# Czas 10:17: Pacjent 9 wychodzi z gabinetu 3, czekal od 10:02 do 10:02
# Czas 10:17: Pacjent 12 wchodzi do gabinetu 3
# Czas 10:21: Pacjent 13 przybył do kliniki
# Czas 10:26: Pacjent 14 przybył do kliniki
# Czas 10:27: Pacjent 10 wychodzi z gabinetu 1, czekal od 10:05 do 10:12
# Czas 10:27: Pacjent 13 wchodzi do gabinetu 1
# Czas 10:27: Pacjent 11 wychodzi z gabinetu 2, czekal od 10:09 do 10:12
# Czas 10:27: Pacjent 14 wchodzi do gabinetu 2
# Czas 10:32: Pacjent 12 wychodzi z gabinetu 3, czekal od 10:13 do 10:17
# Czas 10:37: Pacjent 15 przybył do kliniki
# Czas 10:37: Pacjent 15 wchodzi do gabinetu 3
# Czas 10:38: Pacjent 16 przybył do kliniki
# Czas 10:38: Pacjent 17 przybył do kliniki
# Czas 10:41: Pacjent 18 przybył do kliniki
# Czas 10:42: Pacjent 13 wychodzi z gabinetu 1, czekal od 10:21 do 10:27
# Czas 10:42: Pacjent 16 wchodzi do gabinetu 1
# Czas 10:42: Pacjent 14 wychodzi z gabinetu 2, czekal od 10:26 do 10:27
# Czas 10:42: Pacjent 17 wchodzi do gabinetu 2
# Czas 10:47: Pacjent 19 przybył do kliniki
# Czas 10:52: Pacjent 15 wychodzi z gabinetu 3, czekal od 10:37 do 10:37
# Czas 10:52: Pacjent 18 wchodzi do gabinetu 3
# Czas 10:56: Pacjent 20 przybył do kliniki
# Czas 10:57: Pacjent 16 wychodzi z gabinetu 1, czekal od 10:38 do 10:42
# Czas 10:57: Pacjent 19 wchodzi do gabinetu 1
# Czas 10:57: Pacjent 17 wychodzi z gabinetu 2, czekal od 10:38 do 10:42
# Czas 10:57: Pacjent 20 wchodzi do gabinetu 2
# Czas 10:58: Pacjent 21 przybył do kliniki
# Czas 10:58: Pacjent 22 przybył do kliniki
# Czas 11:01: Pacjent 23 przybył do kliniki
# Czas 11:02: Pacjent 24 przybył do kliniki
# Czas 11:05: Pacjent 25 przybył do kliniki
# Czas 11:06: Pacjent 26 przybył do kliniki
# Czas 11:07: Pacjent 18 wychodzi z gabinetu 3, czekal od 10:41 do 10:52
# Czas 11:07: Pacjent 21 wchodzi do gabinetu 3
# Czas 11:12: Pacjent 19 wychodzi z gabinetu 1, czekal od 10:47 do 10:57
# Czas 11:12: Pacjent 22 wchodzi do gabinetu 1
# Czas 11:12: Pacjent 20 wychodzi z gabinetu 2, czekal od 10:56 do 10:57
# Czas 11:12: Pacjent 23 wchodzi do gabinetu 2
# Czas 11:19: Pacjent 27 przybył do kliniki
# Czas 11:21: Pacjent 28 przybył do kliniki
# Czas 11:22: Pacjent 21 wychodzi z gabinetu 3, czekal od 10:58 do 11:07
# Czas 11:22: Pacjent 24 wchodzi do gabinetu 3
# Czas 11:22: Pacjent 29 przybył do kliniki
# Czas 11:24: Pacjent 30 przybył do kliniki
# Czas 11:27: Pacjent 22 wychodzi z gabinetu 1, czekal od 10:58 do 11:12
# Czas 11:27: Pacjent 25 wchodzi do gabinetu 1
# Czas 11:27: Pacjent 23 wychodzi z gabinetu 2, czekal od 11:01 do 11:12
# Czas 11:27: Pacjent 26 wchodzi do gabinetu 2
# Czas 11:28: Pacjent 31 przybył do kliniki
# Czas 11:33: Pacjent 32 przybył do kliniki
# Czas 11:37: Pacjent 24 wychodzi z gabinetu 3, czekal od 11:02 do 11:22
# Czas 11:37: Pacjent 27 wchodzi do gabinetu 3
# Czas 11:42: Pacjent 25 wychodzi z gabinetu 1, czekal od 11:05 do 11:27
# Czas 11:42: Pacjent 28 wchodzi do gabinetu 1
# Czas 11:42: Pacjent 26 wychodzi z gabinetu 2, czekal od 11:06 do 11:27
# Czas 11:42: Pacjent 29 wchodzi do gabinetu 2
# Czas 11:46: Pacjent 33 przybył do kliniki
# Czas 11:52: Pacjent 27 wychodzi z gabinetu 3, czekal od 11:19 do 11:37
# Czas 11:52: Pacjent 30 wchodzi do gabinetu 3
# Czas 11:55: Pacjent 34 przybył do kliniki
# Czas 11:57: Pacjent 28 wychodzi z gabinetu 1, czekal od 11:21 do 11:42
# Czas 11:57: Pacjent 31 wchodzi do gabinetu 1
# Czas 11:57: Pacjent 29 wychodzi z gabinetu 2, czekal od 11:22 do 11:42
# Czas 11:57: Pacjent 32 wchodzi do gabinetu 2
# Czas 12:02: Pacjent 35 przybył do kliniki
# Czas 12:06: Pacjent 36 przybył do kliniki
# Czas 12:06: Pacjent 37 przybył do kliniki
# Czas 12:07: Pacjent 30 wychodzi z gabinetu 3, czekal od 11:24 do 11:52
# Czas 12:07: Pacjent 33 wchodzi do gabinetu 3
# Czas 12:07: Pacjent 38 przybył do kliniki
# Czas 12:12: Pacjent 31 wychodzi z gabinetu 1, czekal od 11:28 do 11:57
# Czas 12:12: Pacjent 34 wchodzi do gabinetu 1
# Czas 12:12: Pacjent 32 wychodzi z gabinetu 2, czekal od 11:33 do 11:57
# Czas 12:12: Pacjent 35 wchodzi do gabinetu 2
# Czas 12:22: Pacjent 33 wychodzi z gabinetu 3, czekal od 11:46 do 12:07
# Czas 12:22: Pacjent 36 wchodzi do gabinetu 3
# Czas 12:25: Pacjent 39 przybył do kliniki
# Czas 12:27: Pacjent 34 wychodzi z gabinetu 1, czekal od 11:55 do 12:12
# Czas 12:27: Pacjent 37 wchodzi do gabinetu 1
# Czas 12:27: Pacjent 35 wychodzi z gabinetu 2, czekal od 12:02 do 12:12
# Czas 12:27: Pacjent 38 wchodzi do gabinetu 2
# Czas 12:36: Pacjent 40 przybył do kliniki
# Czas 12:37: Pacjent 41 przybył do kliniki
# Czas 12:37: Pacjent 36 wychodzi z gabinetu 3, czekal od 12:06 do 12:22
# Czas 12:37: Pacjent 39 wchodzi do gabinetu 3
# Czas 12:38: Pacjent 42 przybył do kliniki
# Czas 12:39: Pacjent 43 przybył do kliniki
# Czas 12:42: Pacjent 37 wychodzi z gabinetu 1, czekal od 12:06 do 12:27
# Czas 12:42: Pacjent 40 wchodzi do gabinetu 1
# Czas 12:42: Pacjent 38 wychodzi z gabinetu 2, czekal od 12:07 do 12:27
# Czas 12:42: Pacjent 41 wchodzi do gabinetu 2
# Czas 12:47: Pacjent 44 przybył do kliniki
# Czas 12:51: Pacjent 45 przybył do kliniki
# Czas 12:52: Pacjent 39 wychodzi z gabinetu 3, czekal od 12:25 do 12:37
# Czas 12:52: Pacjent 42 wchodzi do gabinetu 3
# Czas 12:57: Pacjent 40 wychodzi z gabinetu 1, czekal od 12:36 do 12:42
# Czas 12:57: Pacjent 43 wchodzi do gabinetu 1
# Czas 12:57: Pacjent 41 wychodzi z gabinetu 2, czekal od 12:37 do 12:42
# Czas 12:57: Pacjent 44 wchodzi do gabinetu 2
# Czas 12:59: Pacjent 46 przybył do kliniki
# Czas 13:07: Pacjent 42 wychodzi z gabinetu 3, czekal od 12:38 do 12:52
# Czas 13:07: Pacjent 45 wchodzi do gabinetu 3
# Czas 13:10: Pacjent 47 przybył do kliniki
# Czas 13:12: Pacjent 43 wychodzi z gabinetu 1, czekal od 12:39 do 12:57
# Czas 13:12: Pacjent 46 wchodzi do gabinetu 1
# Czas 13:12: Pacjent 44 wychodzi z gabinetu 2, czekal od 12:47 do 12:57
# Czas 13:12: Pacjent 47 wchodzi do gabinetu 2
# Czas 13:18: Pacjent 48 przybył do kliniki
# Czas 13:21: Pacjent 49 przybył do kliniki
# Czas 13:22: Pacjent 45 wychodzi z gabinetu 3, czekal od 12:51 do 13:07
# Czas 13:22: Pacjent 48 wchodzi do gabinetu 3
# Czas 13:26: Pacjent 50 przybył do kliniki
# Czas 13:27: Pacjent 46 wychodzi z gabinetu 1, czekal od 12:59 do 13:12
# Czas 13:27: Pacjent 49 wchodzi do gabinetu 1
# Czas 13:27: Pacjent 47 wychodzi z gabinetu 2, czekal od 13:10 do 13:12
# Czas 13:27: Pacjent 50 wchodzi do gabinetu 2
# Czas 13:34: Pacjent 51 przybył do kliniki
# Czas 13:37: Pacjent 48 wychodzi z gabinetu 3, czekal od 13:18 do 13:22
# Czas 13:37: Pacjent 51 wchodzi do gabinetu 3
# Czas 13:42: Pacjent 49 wychodzi z gabinetu 1, czekal od 13:21 do 13:27
# Czas 13:42: Pacjent 50 wychodzi z gabinetu 2, czekal od 13:26 do 13:27
# Czas 13:52: Pacjent 52 przybył do kliniki
# Czas 13:52: Pacjent 52 wchodzi do gabinetu 1
# Czas 13:52: Pacjent 51 wychodzi z gabinetu 3, czekal od 13:34 do 13:37
# Czas 13:53: Pacjent 53 przybył do kliniki
# Czas 13:53: Pacjent 53 wchodzi do gabinetu 2
# Czas 13:56: Pacjent 54 przybył do kliniki
# Czas 13:56: Pacjent 54 wchodzi do gabinetu 3
# Czas 13:59: Pacjent 55 przybył do kliniki
# Czas 14:07: Pacjent 52 wychodzi z gabinetu 1, czekal od 13:52 do 13:52
# Czas 14:07: Pacjent 55 wchodzi do gabinetu 1
# Czas 14:08: Pacjent 53 wychodzi z gabinetu 2, czekal od 13:53 do 13:53
# Czas 14:11: Pacjent 54 wychodzi z gabinetu 3, czekal od 13:56 do 13:56
# Czas 14:18: Pacjent 56 przybył do kliniki
# Czas 14:18: Pacjent 56 wchodzi do gabinetu 2
# Czas 14:22: Pacjent 57 przybył do kliniki
# Czas 14:22: Pacjent 57 wchodzi do gabinetu 3
# Czas 14:22: Pacjent 55 wychodzi z gabinetu 1, czekal od 13:59 do 14:07
# Czas 14:23: Pacjent 58 przybył do kliniki
# Czas 14:23: Pacjent 58 wchodzi do gabinetu 1
# Czas 14:30: Pacjent 59 przybył do kliniki
# Czas 14:32: Pacjent 60 przybył do kliniki
# Czas 14:33: Pacjent 56 wychodzi z gabinetu 2, czekal od 14:18 do 14:18
# Czas 14:33: Pacjent 59 wchodzi do gabinetu 2
# Czas 14:37: Pacjent 57 wychodzi z gabinetu 3, czekal od 14:22 do 14:22
# Czas 14:37: Pacjent 60 wchodzi do gabinetu 3
# Czas 14:38: Pacjent 58 wychodzi z gabinetu 1, czekal od 14:23 do 14:23
# Czas 14:43: Pacjent 61 przybył do kliniki
# Czas 14:43: Pacjent 61 wchodzi do gabinetu 1
# Czas 14:48: Pacjent 62 przybył do kliniki
# Czas 14:48: Pacjent 59 wychodzi z gabinetu 2, czekal od 14:30 do 14:33
# Czas 14:48: Pacjent 62 wchodzi do gabinetu 2
# Czas 14:49: Pacjent 63 przybył do kliniki
# Czas 14:50: Pacjent 64 przybył do kliniki
# Czas 14:51: Pacjent 65 przybył do kliniki
# Czas 14:52: Pacjent 60 wychodzi z gabinetu 3, czekal od 14:32 do 14:37
# Czas 14:52: Pacjent 63 wchodzi do gabinetu 3
# Czas 14:55: Pacjent 66 przybył do kliniki
# Czas 14:58: Pacjent 61 wychodzi z gabinetu 1, czekal od 14:43 do 14:43
# Czas 14:58: Pacjent 64 wchodzi do gabinetu 1
# Czas 14:59: Pacjent 67 przybył do kliniki
# Czas 14:59: Pacjent 68 przybył do kliniki
# Czas 15:03: Pacjent 62 wychodzi z gabinetu 2, czekal od 14:48 do 14:48
# Czas 15:03: Pacjent 65 wchodzi do gabinetu 2
# Czas 15:03: Pacjent 69 przybył do kliniki
# Czas 15:07: Pacjent 70 przybył do kliniki
# Czas 15:07: Pacjent 63 wychodzi z gabinetu 3, czekal od 14:49 do 14:52
# Czas 15:07: Pacjent 66 wchodzi do gabinetu 3
# Czas 15:13: Pacjent 64 wychodzi z gabinetu 1, czekal od 14:50 do 14:58
# Czas 15:13: Pacjent 67 wchodzi do gabinetu 1
# Czas 15:18: Pacjent 71 przybył do kliniki
# Czas 15:18: Pacjent 65 wychodzi z gabinetu 2, czekal od 14:51 do 15:03
# Czas 15:18: Pacjent 68 wchodzi do gabinetu 2
# Czas 15:19: Pacjent 72 przybył do kliniki
# Czas 15:22: Pacjent 66 wychodzi z gabinetu 3, czekal od 14:55 do 15:07
# Czas 15:22: Pacjent 69 wchodzi do gabinetu 3
# Czas 15:25: Pacjent 73 przybył do kliniki
# Czas 15:25: Pacjent 74 przybył do kliniki
# Czas 15:27: Pacjent 75 przybył do kliniki
# Czas 15:27: Pacjent 76 przybył do kliniki
# Czas 15:28: Pacjent 67 wychodzi z gabinetu 1, czekal od 14:59 do 15:13
# Czas 15:28: Pacjent 70 wchodzi do gabinetu 1
# Czas 15:32: Pacjent 77 przybył do kliniki
# Czas 15:33: Pacjent 68 wychodzi z gabinetu 2, czekal od 14:59 do 15:18
# Czas 15:33: Pacjent 71 wchodzi do gabinetu 2
# Czas 15:34: Pacjent 78 przybył do kliniki
# Czas 15:35: Pacjent 79 przybył do kliniki
# Czas 15:36: Pacjent 80 przybył do kliniki
# Czas 15:37: Pacjent 69 wychodzi z gabinetu 3, czekal od 15:03 do 15:22
# Czas 15:37: Pacjent 72 wchodzi do gabinetu 3
# Czas 15:42: Pacjent 81 przybył do kliniki
# Czas 15:43: Pacjent 70 wychodzi z gabinetu 1, czekal od 15:07 do 15:28
# Czas 15:43: Pacjent 73 wchodzi do gabinetu 1
# Czas 15:48: Pacjent 71 wychodzi z gabinetu 2, czekal od 15:18 do 15:33
# Czas 15:48: Pacjent 74 wchodzi do gabinetu 2
# Czas 15:50: Pacjent 82 przybył do kliniki
# Czas 15:52: Pacjent 72 wychodzi z gabinetu 3, czekal od 15:19 do 15:37
# Czas 15:52: Pacjent 75 wchodzi do gabinetu 3
# Czas 15:57: Pacjent 83 przybył do kliniki
# Czas 15:57: Pacjent 84 przybył do kliniki
# Czas 15:58: Pacjent 73 wychodzi z gabinetu 1, czekal od 15:25 do 15:43
# Czas 15:58: Pacjent 76 wchodzi do gabinetu 1
# Czas 15:59: Pacjent 85 przybył do kliniki
# Czas 16:02: Pacjent 86 przybył do kliniki
# Czas 16:03: Pacjent 74 wychodzi z gabinetu 2, czekal od 15:25 do 15:48
# Czas 16:03: Pacjent 77 wchodzi do gabinetu 2
# Czas 16:03: Pacjent 87 przybył do kliniki
# Czas 16:04: Pacjent 88 przybył do kliniki
# Czas 16:05: Pacjent 89 przybył do kliniki
# Czas 16:07: Pacjent 75 wychodzi z gabinetu 3, czekal od 15:27 do 15:52
# Czas 16:07: Pacjent 78 wchodzi do gabinetu 3
# Czas 16:13: Pacjent 76 wychodzi z gabinetu 1, czekal od 15:27 do 15:58
# Czas 16:13: Pacjent 79 wchodzi do gabinetu 1
# Czas 16:17: Pacjent 90 przybył do kliniki
# Czas 16:18: Pacjent 77 wychodzi z gabinetu 2, czekal od 15:32 do 16:03
# Czas 16:18: Pacjent 80 wchodzi do gabinetu 2
# Czas 16:18: Pacjent 91 przybył do kliniki
# Czas 16:19: Pacjent 92 przybył do kliniki
# Czas 16:22: Pacjent 78 wychodzi z gabinetu 3, czekal od 15:34 do 16:07
# Czas 16:22: Pacjent 81 wchodzi do gabinetu 3
# Czas 16:24: Pacjent 93 przybył do kliniki
# Czas 16:24: Pacjent 94 przybył do kliniki
# Czas 16:28: Pacjent 95 przybył do kliniki
# Czas 16:28: Pacjent 79 wychodzi z gabinetu 1, czekal od 15:35 do 16:13
# Czas 16:28: Pacjent 82 wchodzi do gabinetu 1
# Czas 16:29: Pacjent 96 przybył do kliniki
# Czas 16:33: Pacjent 80 wychodzi z gabinetu 2, czekal od 15:36 do 16:18
# Czas 16:33: Pacjent 83 wchodzi do gabinetu 2
# Czas 16:37: Pacjent 81 wychodzi z gabinetu 3, czekal od 15:42 do 16:22
# Czas 16:37: Pacjent 84 wchodzi do gabinetu 3
# Czas 16:40: Pacjent 97 przybył do kliniki
# Czas 16:43: Pacjent 98 przybył do kliniki
# Czas 16:43: Pacjent 82 wychodzi z gabinetu 1, czekal od 15:50 do 16:28
# Czas 16:43: Pacjent 85 wchodzi do gabinetu 1
# Czas 16:48: Pacjent 83 wychodzi z gabinetu 2, czekal od 15:57 do 16:33
# Czas 16:48: Pacjent 86 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 87 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 88 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 89 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 90 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 91 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 92 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 93 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 94 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 95 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 96 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 97 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:48: Pacjent 98 - nie zdążył zostać obsłużony przed zamknięciem kliniki
# Czas 16:52: Pacjent 84 wychodzi z gabinetu 3, czekal od 15:57 do 16:37
# Czas 16:58: Pacjent 85 wychodzi z gabinetu 1, czekal od 15:59 do 16:43

# %%
clinic.queue_array
# Out:
# [86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98]

# %%
clinic.stats()
